# %%
import matplotlib.pyplot as plt

# %%
def g2(x):
  return (5/(2*x-1))

# %%
x_vec=[]
x_vec.append(0)
contador=int(input("inserte el contador: "))
error_vec=[]
error_vec.append(float(input("inserte el error ")))
criterio_paro=float(input("inserte el criterio de paro: "))
limite=int(input("inserte el limite "))
# Out:
# inserte el contador: 0
# inserte el error 1
# inserte el criterio de paro: 0.0001
# inserte el limite 10

# %%
while((contador <= limite) and error_vec[contador] > criterio_paro):
  x_temp=g2(x_vec[contador])
  x_vec.append(x_temp)
  e_temp=abs(x_vec[contador+1]-x_vec[contador])
  error_vec.append(e_temp)
  contador+=1
  if (x_vec[contador]>5555):
    Converge=False
    print("no converge")
  else:
    if (x_vec[contador]<5555):
      Converge=True
      print("Converge")

# %%
print(error_vec)
# Out:
# [1.0, 5.0, 4.545454545454546, 2.1645021645021645, 1.8175209014903673, 1.1192943968122497, 0.8881136643392169, 0.598393122979002, 0.4579977961329249, 0.32112700658465987, 0.24061296320613357, 0.17200819150601943]

# %%
print(x_vec)
# Out:
# [0, -5.0, -0.45454545454545453, -2.619047619047619, -0.8015267175572519, -1.9208211143695015, -1.0327074500302846, -1.6311005730092867, -1.1731027768763618, -1.4942297834610216, -1.253616820254888, -1.4256250117609075]

# %%
plt.plot(error_vec)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.plot(x_vec)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
import matplotlib.pyplot as plt

# %%
def g2(x):
  return ((2*x**2)-5)

# %%
x_vec=[]
x_vec.append(0)
contador=int(input("inserte el contador: "))
error_vec=[]
error_vec.append(float(input("inserte el error ")))
criterio_paro=float(input("inserte el criterio de paro: "))
limite=int(input("inserte el limite "))0
# Out:
# inserte el contador: 1
# inserte el error 0
# inserte el criterio de paro: 0.001
# inserte el limite 4

# %%
while((contador <= limite) and error_vec[contador] > criterio_paro):
  x_temp=g2(x_vec[contador])
  x_vec.append(x_temp)
  e_temp=abs(x_vec[contador+1]-x_vec[contador])
  error_vec.append(e_temp)
  contador+=1

  
  if (x_vec[contador]>5555):
    Converge=False
    print("no converge")
  else:
    if (x_vec[contador]<5555):
      Converge=True
      print("Converge")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-74-c8297ba6b366> in <module>()
# ----> 1 while((contador <= limite) and error_vec[contador] > criterio_paro):
#       2   x_temp=g2(x_vec[contador])
#       3   x_vec.append(x_temp)
#       4   e_temp=abs(x_vec[contador+1]-x_vec[contador])
#       5   error_vec.append(e_temp)
#
# IndexError: list index out of range

# %%
print(x_vec)
# Out:
# [0, -5.0, -0.45454545454545453, -2.619047619047619, -0.8015267175572519, -1.9208211143695015, -1.0327074500302846, -1.6311005730092867, -1.1731027768763618, -1.4942297834610216, -1.253616820254888, -1.4256250117609075, -1.2982797713630907, -1.3902174955262983, -1.322599122014749, -1.3716675103170435, -1.3357073231326875, -1.361872869654231, -1.3427339969051033, -1.356679805223534, -1.3464895740054725, -1.3539204527306963]

# %%
print(error_vec)
# Out:
# [0.0]

# %%
plt.plot(x_vec)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.plot(error_vec)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
import matplotlib.pyplot as plt
import math

# %%
def g2(x):
  return (math.sqrt((x+5)/2))

# %%
x_vec=[]
x_vec.append(0)
contador=int(input("inserte el contador: "))
error_vec=[]
error_vec.append(float(input("inserte el error ")))
criterio_paro=float(input("inserte el criterio de paro: "))
limite=int(input("inserte el limite ")

# %%
while((contador <= limite) and error_vec[contador] > criterio_paro):
  x_temp=g2(x_vec[contador])
  x_vec.append(x_temp)
  e_temp=abs(x_vec[contador+1]-x_vec[contador])
  error_vec.append(e_temp)
  contador+=1
  if (x_vec[contador]>5555):
    Converge=False
    print("no converge")
  else:
    if (x_vec[contador]<5555):
      Converge=True
      print("Converge")

# %%
print(error_vec)
# Out:
# [0.0]

# %%
print(x_vec)
# Out:
# [0]

# %%
plt.plot(x_vec)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.plot(error_vec)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
import matplotlib.pyplot as plt
import math

# %%
def g2(x):
  return (-(math.sqrt((x+5)/2)))

# %%
x_vec=[]
x_vec.append(0)
contador=int(input("inserte el contador: "))
error_vec=[]
error_vec.append(float(input("inserte el error ")))
criterio_paro=float(input("inserte el criterio de paro: "))
limite=int(input("inserte el limite "))

# %%
while((contador <= limite) and error_vec[contador] > criterio_paro):
  x_temp=g2(x_vec[contador])
  x_vec.append(x_temp)
  e_temp=abs(x_vec[contador+1]-x_vec[contador])
  error_vec.append(e_temp)
  contador+=1
  if (x_vec[contador]>5555):
    Converge=False
    print("no converge")
  else:
    if (x_vec[contador]<5555):
      Converge=True
      print("Converge")

# %%
print(x_vec)
# Out:
# [0]

# %%
print(error_vec)
# Out:
# [0.0]

# %%
plt.plot(x_vec)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.plot(error_vec)
plt.show
# Out:
# <function matplotlib.pyplot.show>
